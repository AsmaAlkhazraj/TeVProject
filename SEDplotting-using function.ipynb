# %%
from SEDlibrary import SEDplt

# %%
SEDplt('PG1553+113.txt','PG1553+113')

# %%
SEDplt('BLLacertae.txt','BL Lacertae')

# %%
SEDplt('3C66A.txt','3C 66A')

# %%
SEDplt('MARKARIAN180.txt','MKN180')

# %%
SEDplt('1ES0229+200.txt','1ES 0229+200')

# %%
SEDplt('1ES1011+496.txt','1ES 1011+496')

# %%
SEDplt('RGBJ0152+017.txt','RGB J0152+017')

# %%
SEDplt('WCOMAE.txt','W Comae')

# %%
SEDplt('1ES0806+524.txt','1ES 0806+524')

# %%
SEDplt('MAGICJ2001+435.txt','MAGIC J2001+435')

# %%
SEDplt('3C279.txt','3C 279')

# %%
SEDplt('S50716+714.txt','S5 0716+714')

# %%
SEDplt('RGBJ0710+591.txt','RGB J0710+591')

# %%
SEDplt('PKS1424+240.txt','PKS1424+240')

# %%
SEDplt('VERJ0521+211.txt','VER J0521+211')
